# %%
### Imports and initialization ###
import brianNetworkConsolidation as bnc
# %matplotlib inline
import json
from brian2.units import msecond, second, mvolt, namp, ncoulomb, Mohm, pfarad, hertz, farad
minute = 60*second
hour = 60*minute

# %%
### Running the simulation ###
config_file = "config_smallnet2.json"
config = json.load(open(config_file, "r"))
config["simulation"]["short_description"] = "smallnet2, dt=0.2"
config["simulation"]["runtime"] = 0.2 # second
config["simulation"]["dt"] = 0.2 # msecond

bnc.run(config, ['V', 'p'], ['h', 'z', 'Ca'], interactive=True)

#print("neur_state_mon.V[0] =", neur_state_mon.V[0])
# Out:
# Brian network simulation 24-04-11_02-36-04 (Brian version: 2.5.1)
# |
# Simulated timespan: 0.2 s
# Population parameters: N_exc = 4, N_inh = 0
# Learning protocol: FULL (OU), 2000 input neurons at 1 Hz, starting at 0 s
# Recall protocol: none
# Background input: none
# |
# Loading connections from file.
# Starting simulation at t=0 s for duration 0.2 s
# 0.2 s (100%) simulated in < 1s
# Simulation completed (in 2 s).
# Data stored (in <1 s).
# Plotting completed (in 4 s).
# Retrieval of connectivity matrix completed (in <1 s).
# Number of connections: 5 (expected value: -12).
# Total elapsed time: 6 s.
